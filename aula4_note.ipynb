# %%
simbolo = [
    'IFNG', 
    'IL10', 
    'TNF',
    'CSF2'
]
full_name = [
    'interferon gamma',
    'interleucina 10', 
    'tumor necrosis factor',
    'colony stimulating factor 2'
]
source = [
    'HGNC:HGNC:5438', 
    'RGD:2886', 
    'MGI:MGI:104798', 
    'HGNC:HGNC:2434'
]
gene_type = [
    'protein coding',
    'protein coding', 
    'protein coding', 
    'protein coding'
]
organism = [
    'Homo sapiens', 
    'Rattus norvegicus', 
    'Mus musculus',
    'Homo sapiens'
]
chromosome = [
    12,
    13,
    17,
    5
]

# %%
gene_matriz_lista = [
    simbolo,
    full_name,
    source,
    gene_type,
    organism,
    chromosome
]
gene_matriz_lista
# Out:
# [['IFNG', 'IL10', 'TNF', 'CSF2'],
#  ['interferon gamma',
#   'interleucina 10',
#   'tumor necrosis factor',
#   'colony stimulating factor 2'],
#  ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#  ['protein coding', 'protein coding', 'protein coding', 'protein coding'],
#  ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus', 'Homo sapiens'],
#  [12, 13, 17, 5]]

# %%
import pandas
import numpy

# %%
dicionario = {
    "simbolo": simbolo,
    "full_name": full_name,
    "source":     source,
    "gene_type": gene_type,
    "organism":  organism,
    "chromosome": chromosome
}
dicionario
# Out:
# {'simbolo': ['IFNG', 'IL10', 'TNF', 'CSF2'],
#  'full_name': ['interferon gamma',
#   'interleucina 10',
#   'tumor necrosis factor',
#   'colony stimulating factor 2'],
#  'source': ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#  'gene_type': ['protein coding',
#   'protein coding',
#   'protein coding',
#   'protein coding'],
#  'organism': ['Homo sapiens',
#   'Rattus norvegicus',
#   'Mus musculus',
#   'Homo sapiens'],
#  'chromosome': [12, 13, 17, 5]}

# %%
simbolo.append('actina') #toda vez que roda acrescenta um novo
simbolo

# %%
dicionario['simbolo'].append('vir')
print(dicionario)
print(simbolo)

# %%
import numpy

# %%
gene_array = numpy.array(gene_matriz_lista)
gene_array
# Out:
# array([['IFNG', 'IL10', 'TNF', 'CSF2'],
#        ['interferon gamma', 'interleucina 10', 'tumor necrosis factor',
#         'colony stimulating factor 2'],
#        ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#        ['protein coding', 'protein coding', 'protein coding',
#         'protein coding'],
#        ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus',
#         'Homo sapiens'],
#        ['12', '13', '17', '5']], dtype='<U27')

# %%
gene_array.shape #tamanho da matriz linha, coluna
# Out:
# (6, 4)

# %%
gene_array[0:3]
# Out:
# array([['IFNG', 'IL10', 'TNF', 'CSF2'],
#        ['interferon gamma', 'interleucina 10', 'tumor necrosis factor',
#         'colony stimulating factor 2'],
#        ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434']],
#       dtype='<U27')

# %%
#seleação de linhas especificas
index= [1,3, 4]
gene_array[[index]]
gene_array[[0,2]] #seleação de linhas especificas
# Out:
# array([[['interferon gamma', 'interleucina 10', 'tumor necrosis factor',
#          'colony stimulating factor 2'],
#         ['protein coding', 'protein coding', 'protein coding',
#          'protein coding'],
#         ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus',
#          'Homo sapiens']]], dtype='<U27')

# %%
#seleção de linha específicas
gene_array[:,0]
gene_array[:,[1,0]] #quando duas linhas
# Out:
# array([['IL10', 'IFNG'],
#        ['interleucina 10', 'interferon gamma'],
#        ['RGD:2886', 'HGNC:HGNC:5438'],
#        ['protein coding', 'protein coding'],
#        ['Rattus norvegicus', 'Homo sapiens'],
#        ['13', '12']], dtype='<U27')

# %%
#seleção do ultimo elemento 
gene_array[-1,1:3] #ultima linhas coluna 1 e 2
# Out:
# array(['13', '17'], dtype='<U27')
