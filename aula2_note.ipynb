# %%
#Objetos simples - String, Integer, Float, Booleand, Complex, bytes
#A ideia é que tenhamos moldes no código para fazer as coisas --> toda vez que você aciona aquele código sempre vai solucionar os mesmos problemas 
#Definimos objetos dentro da linguagem que irão possuir caracteristicas e funções --> Abstração (abstrair o mundo físico dentro do programa)
#Abstração da ideia física de uma objeto para a computacional> Instância (nome); Atributos (caracteristicas); Método (opções classe); Função (ações livres - não necessariamente ligada ao objeto)
#"String" é um objeto --> metodo de instância, atributos, métodos e ser utilizado em funções 
#Objetos são instancias de classe (dar um nome) --> Variaveis são objetos instanciados 
#Instanciando objeto do tipo string: 
lâmpada = "led" #declarar a variável (atribuir o valor para o objeto), assim, a lâmpada foi atribuida para led
#Pegando um atributodo objeto string:
lâmpada.__getattribute__ #nome_objeto.nome_atributo
#Usando um método do objeto string:
lâmpada.upper() #nome_objeto.nome_método(parâmetro[opcional])
#Definindo e usando uma função para desligar a lâmpada:
def desligar(lâmpada: str) -> str:
    lâmpada = "desligada"
    return lâmpada
desligar(lâmpada) #nome_objeto.nome_função(parâmetro[opcional])
#Método local (ver o valor atribuido ao objeto):
lâmpada.count("a") #nome_objeto.nome_método(parâmetro[opcional])
#Método global:
print(lâmpada) #nome_objeto(parãmetro[opcional] = nome_objeto)
#Uso de variáveis 
help(lâmpada)
help(type(lâmpada)
help(função)
dir(lâmpada) --> #abstrações do objeto
#Nomes de variáveis: objetos, classes e funções-> não podem ser iniciador com números; não utilizar símbolos exceto_; comentários são escritos com #; Não podem ser palavras reservadas
#IDE --> Ambiente Integral de Desenvolvimento (quem ajuda e auxilia nos codigos e sugestões)
#PRÁTICA:
#Objeto simples - cadeia de caracteres alpha numérico str:""
#Inteiros - números inteiros  int: 4,5,..
#Flutuantes - números decimais float: 4.2, 5.5...
#Booleanos - valores binários (lógicos) bool: false, true
#Complexo - númeor complexo (real imaginário) complex: 24+7j
#Bytes - cadeia de caracteres em ASCII  bytes:b'\xx0\x00\x00...

# %%
import this
