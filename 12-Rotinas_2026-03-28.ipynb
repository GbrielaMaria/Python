# %% [markdown]
# # Explicação Rotina
#
# https://1drv.ms/v/c/808ebfd9a0d86213/IQA1p5nBtUMiS4C1k70ZRFf3ASpmGVhaRHc_ibt9GJbkfww?e=9Er6z5

# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Cite três vantagens do uso das funções e duas características que toda função deva ter?

# %% [markdown]
# R.:As vantagens do usa das funções é a reutilização de códgio, organização e legibilidade, e facilidade de manutenção; ou seja, as funções permitem escrever um bloco de código uma vez e utilizá-lo várias vezes, evitando repetição e tornando o programa mais eficiente; além de dividir o programa em partes menores e mais compreensíveis, facilitando a leitura, manutenção e depuração do código.

# %% [markdown]
# ## Responda a pergunta do exercício 2 da aula 10, usando funções:<br>
# Instancie um objeto da classe NumPy array, contendo 5 valores quantitativos randômicos normalmente distribuídos, com média 10 e desvio padrão 3.<br><br>
# Quantos e quais são os valores superiores a 10?

# %% [markdown]
# ## 02 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: Utilizando o NumPy foi gerado 5 valores aleatórios seguindo uma distribuição normal com média 10 e desvio padrão 3.A partir disso, foi aplicada uma função vetorizada para identificar diretamente os elementos superiores a 10, sem necessidade de estruturas de repetição explícitas.E para fazer a comparação arr>10 foi retornado um boleano que permitiu filtrar os valores de forma eficiente.

# %% [markdown]
# ## 03 – Desenhe o fluxograma da resposta:

# %% [markdown]
# <img src="fluxogramapython6.jpg">

# %% [markdown]
# ## 04 – Escreva o programa em Python:

# %%
#Importação do pacote
import numpy as np
#Array
def gerar_array():
    return np.random.normal(loc=10, scale=3, size=5)

def valores_maiores_que_10(arr):
    maiores = arr[arr > 10]
    return len(maiores), maiores

np.random.seed(42)  # reprodutibilidade 
array = gerar_array()
quantidade, valores = valores_maiores_que_10(array)

print(array)
print(quantidade)
print(valores)
# Out:
# [11.49014246  9.5852071  11.94306561 14.56908957  9.29753988]
# 3
# [11.49014246 11.94306561 14.56908957]

# %% [markdown]
# ## 05 – Seria possível, com o racional proposto, saber quantos e quais valores são superiores a 20? Porque?

# %% [markdown]
# R: Sim, seria possível utilizando o mesmo raciocínio proposto anteriormente, uma vez que o racional se baseia em operações vetorizadas, onde a comparação entre o array e um valor escalar gera automaticamente uma masca booleana

# %% [markdown]
# ## Desenvolva um programa de computador que retorne a média de um conjunto de valores.

# %% [markdown]
# ## 06 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: A média aritmética de um conjunto de valores é calculada somando todos os elementos (sum(valores)) e dividindo pela quantidade total de elementos (len(valores)).

# %% [markdown]
# ## 07 – Desenhe o fluxograma da resposta:

# %% [markdown]
# <img src="fluxogramapython7.jpg">

# %% [markdown]
# ## 07 – Escreva o programa em Python:

# %%
valores = [10, 15, 20, 25, 30]
print(valores)
#Media
media = sum(valores) / len(valores)
print(media)
# Out:
# [10, 15, 20, 25, 30]
# 20.0

# %% [markdown]
# ## 09 – Desenvolva um programa de computador que retorne a divisão de dois objetos simples. Seu programa deve ser capaz de reconhecer a classe destes objetos e o valor, antes de retornar ao usuário.

# %%
def dividir(a, b):
    print(type(a))
    print(type(b))
    if b == 0:
        return "Erro: divisão por zero não é permitida."
    return a / b

x = 10
y = 2
resultado = dividir(x, y)
print(resultado)
# Out:
# <class 'int'>
# <class 'int'>
# 5.0

# %% [markdown]
# ## 10 – Desenvolva um programa de computador que retorne a divisão de dois objetos compostos. Seu programa deve ser capaz de reconhecer a classe destes objetos e o valor, antes de retornar ao usuário.

# %%
def dividir_objetos(a, b):
    print(type(a))
    print(type(b))
    #tuplas
    a = list(a)
    b = list(b)
    if len(a) != len(b):
        return "Erro: objetos devem ter o mesmo tamanho."
    resultado = []
    for i in range(len(a)):
        if b[i] == 0:
            resultado.append(None)  # evita divisão por zero
        else:
            resultado.append(a[i] / b[i])

    return resultado

x = [10, 20, 30]
y = [2, 4, 5]
print(dividir_objetos(x, y))
# Out:
# <class 'list'>
# <class 'list'>
# [5.0, 5.0, 6.0]
