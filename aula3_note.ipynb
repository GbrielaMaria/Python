# %%
#Ao instanciar um objeto podemos instanciar com mais de um valor, chamando de objeto composto e podem pertencer a diferentes classes
#nome_objeto_simples = valor
#nome_objeto_composto = [valor] --> conchetes vai ser uma indicação para lista :
#para chamar os valores dessa lista colocar: print(lamps[0]), como o exemplo 
lamps = [
    "ligada", 
    "desligada", 
    "desligada", 
    "ligada"
]
print(lamps[0])
print(lamps[1])
#para count ou qualquer outra fução chamamos:
lamps[0].count("a") #sempre indicar na lista qual linha você quer se referenciar, sendo que essa lista começa na linha 0 e as funções devem ser equivalentes ao tipo de classe que sua instancia equivale
#Dicionário devem ter sua classe indicada, como por exemplo:
obj_dicionario = {
    "str": "ligada",
    "int": 50,
    "float": 2.5,
    "bool": True
}
obj_dicionario
#Delimitadores do objeto composto:Tupla: () *auto indexada imuntável; Lista: [] *auto indexada mutável, Dicionario: {"":} *index manual mutável, Set: {} *não repete as informações, *sem index mutável, DataFrame: Pandas; Array: NumPy --> os valores atribuidos podem ser multiclasses
#Tuplas e string --> podemos fazer o mesmo com lsita também:
nome_tupla = ("P", "y", "t", "h", "o", "n")
print(nome_tupla)
nome_tupla[1:4] #vai daqui até aqui --> chamar apenas aquele intervalo
nome_string = "Python"
nome_string[1]
nome_string[1:4]

#Parte prática:
obj_compost1 = ("1", "2", "3")
print(obj_compost1)
print(type(obj_compost1))
print(obj_compost1[2])
obj_compost2 = "1, 2, 3"
print(obj_compost2)
print(type(obj_compost2[2])) #para achar os elementos da lsita podemos fazer pelo último onde ele é -1, o penultimo -2...
obj_compost3 = ["1", "2", "3", "4"]
print(obj_compost3[1])
print(type(obj_compost3))
#exemplo: 
lista = [1, 2, 3, 4 ]
print(f"lista bacana: {lista}")
lista.append('6')
print(f"lista bacan: {lista}")
lista.pop() #exclui o ultimo


obj_dicionario[1]=False
obj_dicionario
# Out:
# ligada
# desligada
# ('P', 'y', 't', 'h', 'o', 'n')
# ('1', '2', '3')
# <class 'tuple'>
# 3
# 1, 2, 3
# <class 'str'>
# 2
# <class 'list'>
# lista bacana: [1, 2, 3, 4]
# lista bacan: [1, 2, 3, 4, '6']
# [1, 2, 3, 4]
# {'str': 'ligada', 'int': 50, 'float': 2.5, 'bool': True, 1: False}

# %%
#Objetos compostos multidimensionais (matrizes) : Numpy e Pandas
matriz = [
    [1,2],
    [3,4], 
    [5,6]
]
matriz
matriz[0][0] = "1"
matriz

#Bibliotecas: SciPy / para chamar pacote :
import nome do pacote as nome que você quer 
#Numpy: usado para calculos - matriz
#Pandas:  usado para dataframe
# Out:
# [['1', 2], [3, 4], [5, 6]]
