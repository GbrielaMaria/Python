# %%
#Operadores aritméticos 
#soma + --> resultado = obj1 + obj2
#subtração - --> resultado = obj1 - obj2
#multiplicação * --> resultado = obj1 * obj2
#divisao / --> resultado = obj1/obj2
#inteiro da divisão // --> resultado = obj1//obj2
#resto da divisão % --> resultado = obj1% obj2
#exponencial ** --> resultado = obj1**obj2
#recebe = --> obj = valor
#+= soma em algo que já existe --> resultado += obj1
#-=; *=, /=, //=, %=, **= ... 
#() --> realizado antes de qq coisa
#Array eu consigo somar numeros nos meus numeros presentes nas listas! Diferente da tupla que não conseguimos! --> o array ele normaliza todos os objetos em uma mesma classe

# %%
#Operadores relacionais : relaciona uma coisa com a outra
#Igualdade == 
#Diferença =! (nega a igualdade)
#> maior 
#>= maior igual 
#< menor 
#<= menor igual
#<=< entre 
#quando tupla: retorno em boleano, quando em coparação entre cada item e cada item da tupla mas retorna apenas o geral; podemos ainda comparar uma tupla com uma lista (mas não compara os valores)
#quando array: retorno em boleano mas faz comparação valor por valor --> so funciona entre arrays com a mesma quantidade de valor
#quando dataframe: retorno em boleano mas faz comparação valor por valor

# %%
#Operadores lógicos
#and : ambos verdadeiros retorna verdadeiro --> 5==5 e 2==2 = TRUE; se qualquer um é falso retorna = False...
#or : um é verdadeiro retorna verdadeiro --> 5==5 ou 2=!2 = True...
#in : presente (existe tal coisa dentro de outra coisa --> 2 in [1,2,3]=True)
#in not : ausente
#is : é (tal coisa é outra coisa --> obj1 is obj2=False)
#is not : não é
